# %%
import requests
from datetime import datetime, timedelta
import google.generativeai as genai

def get_weather_forecast(location):
    """Fetch 5-day weather forecast for the location."""
    weather_api_key = "02554c67125d9439122eaf780220d810"
    url = f"https://api.openweathermap.org/data/2.5/forecast?q={location}&units=metric&appid={weather_api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        forecasts = []
        for entry in data['list'][:5]:
            date = entry['dt_txt'].split(" ")[0]
            temp = entry['main']['temp']
            condition = entry['weather'][0]['description']
            forecasts.append(f"{date}: {temp}°C, {condition}")
        return forecasts
    else:
        return ["Weather data unavailable"]

def get_places_to_visit(location):
    """Fetch popular tourist attractions in the location."""
    google_places_api_key = "AIzaSyBOoDCqCkmhXLzqGkXNzXir0oA1ullGG0w"
    url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query=top+attractions+in+{location}&key={google_places_api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        attractions = [place['name'] for place in data['results'][:5]]  # Get top 5 attractions
        return attractions
    else:
        return ["Attractions data unavailable"]

def generate_trip_plan(destination, origin, departure_date, suggestions):
    """Generate a detailed trip plan."""
    try:
        prompt = (f"Create a detailed and practical trip itinerary for a traveler going from {origin} to {destination} on {departure_date}. "
                  "The itinerary should include the following details:\n"
                  "- Recommended flights with timings and estimated costs.\n"
                  "- Suggested accommodations with price ranges and locations.\n"
                  "- A list of must-visit attractions or historical sites in the destination.\n"
                  "- Weather forecast for the duration of the trip.\n"
                  "- Any additional travel tips or recommendations for dining, transport, and local culture."
                  "- The output should be clean and formatted."
                  f"Take the user suggestions into consideration for the plan: {suggestions}")
        model = genai.GenerativeModel("gemini-1.5-flash")

        # Generate response
        response = model.generate_content(prompt)
        if response:
            return response.text
        else:
            return "Could'nt make a plan!"
    except Exception as e:
        print(f"Could'nt make a plan!: {e}")
        return "Could'nt make a plan!"

# Example Usage
destination = input("Enter your destination: ")
origin = input("Enter your origin: ")
departure_date = input("Enter your departure date (YYYY-MM-DD): ")
suggestions = input("Any Suggestions?: ")

plan = generate_trip_plan(destination, origin, departure_date, suggestions)

# %%
from googletrans import Translator

def translate_text(text, src_lang, dest_lang):
    translator = Translator()
    result = translator.translate(text, src=src_lang, dest=dest_lang)
    return result.text

text = plan
src_lang = "en" 
dest_lang = "mr"  

translated_text = translate_text(text, src_lang, dest_lang)
print(f"Translated text: {translated_text}")
# Out:
# Translated text: ## मुंबई ते पुणे ट्रिप प्रवास: 3 फेब्रुवारी, 2025 (5 तासांची सहल जास्तीत जास्त)
#
# हा कार्यक्रम मुंबईहून पुण्यातील दिवसाच्या सहलीवर लक्ष केंद्रित करतो, आपला वेळ कार्यक्षमतेने जास्तीत जास्त करतो.जास्त काळ मुक्काम केल्यास अधिक आरामशीर अन्वेषण होऊ शकेल.
#
# ** टीप: ** फ्लाइटची वेळ आणि खर्च अंदाज आहेत आणि ते बदलण्याच्या अधीन आहेत.उत्तम किंमतींसाठी आगाऊ बुकिंगची शिफारस केली जाते.3 फेब्रुवारी, 2025 बरेच दूर आहे, म्हणून अद्याप अचूक फ्लाइट डेटा उपलब्ध नाही.
#
#
# ** 1.प्रवास: **
#
# *** पर्याय 1 (सर्वात वेगवान): फ्लाइट: **
# *** एअरलाइन्स: ** इंडिगो, स्पाइसजेट, एअरएशिया इंडिया बहुधा उड्डाणे देण्याची शक्यता आहे.
# *** अंदाजित उड्डाण वेळ: ** ~ 30 मिनिटे.
# *** अंदाजित किंमत: ** ₹ 2,000 - ₹ 5,000 (राउंड ट्रिप).हे बुकिंग वेळ आणि एअरलाइन्सवर आधारित मोठ्या प्रमाणात बदलू शकते.
# *** उदाहरण वेळापत्रक (काल्पनिक): **
# * मुंबई (बॉम) ते पुणे (पीएनक्यू): सकाळी: 00: ०० - सकाळी: 30. .०
# * पुणे (पीएनक्यू) ते मुंबई (बीओएम): संध्याकाळी: 00: ०० - संध्याकाळी: 30 :: 30० (हे पुणेला 5 तासांच्या सहलीला परवानगी देते).
# *** पर्याय 2 (अधिक निसर्गरम्य, परंतु लांब): ट्रेन: ** हा पर्याय 5 तासांच्या मर्यादेपेक्षा जास्त असेल.छोट्या दिवसाच्या सहलीसाठी याची शिफारस केलेली नाही.
#
#
# ** 2.निवास (रात्रभर राहिल्यास-5 तासांच्या सहलीसाठी शिफारस केलेली नाही): **
#
# वापरकर्त्याने त्यांची सहल वाढविण्याची इच्छा असल्यास हा विभाग समाविष्ट केला आहे.
#
# *** बजेट: ** झोस्टेल पुणे, फॅबोटेल, ट्रीबो हॉटेल्स (lay 1,000 - lay 3,000 प्रति रात्री).स्थाने बदलतात, आपल्या नियोजित दर्शनासाठी एक सोयीस्कर निवडा.
# *** मिड -रेंज: ** नोव्होटेल पुणे, मॅरियटचे अंगण (land 4,000 - lay 8,000 प्रति रात्री)
# *** लक्झरी: ** ओबेरॉय, जेडब्ल्यू मॅरियट (प्रति रात्री 10,000 डॉलर)
#
#
# ** 3.भेट देणे आवश्यक आहे आकर्षणे (आपल्या आवडी आणि उपलब्ध वेळेच्या आधारे प्राधान्य द्या): **
#
# 5 तासांच्या वेळेची मर्यादा दिल्यास, एक किंवा दोन ठिकाणी लक्ष केंद्रित करणे वास्तववादी आहे.पुण्यातील स्थानांमधील प्रवासास वेळ लागेल.
#
# *** शनीवार वाडा: ** एक ऐतिहासिक किल्ला, आर्किटेक्चर आणि ऐतिहासिक महत्त्व पहाणे आवश्यक आहे.कमीतकमी 1.5-2 तासांना परवानगी द्या.
# *** आगा खान पॅलेस: ** महात्मा गांधींच्या तुरूंगवासाशी संबंधित आणखी एक महत्त्वपूर्ण ऐतिहासिक साइट.1-1.5 तासांना परवानगी द्या.
# *** उस्मानाबाद: ** एक सुंदर बाग, आरामशीर टहलसाठी छान.(वेळ परवानगी)
#
#
# ** 4.हवामान अंदाज (3 फेब्रुवारी, 2025 - अंदाज): **
#
# पुण्यात फेब्रुवारी सामान्यत: आनंददायी असते, सरासरी तापमान 15 डिग्री सेल्सियस ते 28 डिग्री सेल्सियस पर्यंत असते.सनी दिवस आणि थंड संध्याकाळची अपेक्षा करा.हा फक्त एक अंदाज आहे;तारखेच्या जवळ एक विश्वसनीय हवामान अंदाज तपासा.
#
#
# ** 5.अतिरिक्त ट्रॅव्हल टिप्स: **
#
#
# *** पुण्यातील वाहतूक: ** सोयीस्कर आणि परवडणार्‍या वाहतुकीसाठी ओला किंवा उबर सारख्या राइड-हेलिंग अ‍ॅप्सचा वापर करा.ऑटो-रिक्षा देखील सहज उपलब्ध आहेत परंतु भाड्याने यापूर्वी बोलणी करतात.
# *** जेवण: ** पुणे एक वैविध्यपूर्ण पाक देखावा देते.स्ट्रीट फूडपासून ते उत्तम जेवणापर्यंत प्रत्येकासाठी काहीतरी आहे.आपल्या निवडलेल्या आकर्षणाजवळील स्थानिक रेस्टॉरंट्स एक्सप्लोर करा.प्रसिद्ध पुणे मिसळ पाव वापरुन पहा.
# *** स्थानिक संस्कृती: ** पुणे हा इतिहास आणि आधुनिकतेचे मिश्रण आहे.स्थानिक चालीरिती लक्षात ठेवा आणि धार्मिक साइटला भेट देताना माफक प्रमाणात वेषभूषा करा.
# *** सुरक्षा: ** पुणे सामान्यत: सुरक्षित असते, परंतु लहान चोरीच्या विरूद्ध, विशेषत: गर्दीच्या भागात मानक खबरदारी घेतात.
#
#
# ** 6.नमुना कार्यक्रम (5 तास दिवसाची सहल): **
#
# * सकाळी 9:30 वाजता: पुणे विमानतळावर (पीएनक्यू) पोहोचा.प्री-बुक केलेली टॅक्सी किंवा ओला/उबरला शनीवार वाडा घ्या.
# * सकाळी 10:00 - दुपारी 12:00 वाजता: शनीवार वाडा एक्सप्लोर करा.
# * 12:00 दुपारी - दुपारी 1:00 वाजता: शनीवार वाडाजवळील स्थानिक रेस्टॉरंटमध्ये दुपारचे जेवण.
# * 1:00 दुपारी - 2:00 दुपारी: आगा खान पॅलेसला भेट द्या (जर वेळ परवानगी देत ​​असेल तर अन्यथा विमानतळाकडे जा).
# * 2:30 दुपारी: पुणे विमानतळावर जा (पीएनक्यू).
# * 5:00 दुपारी: पुणे येथून निघून जा.
#
# ** महत्वाची टीप: ** हे एक घट्ट वेळापत्रक आहे.आपल्या प्राधान्ये आणि संभाव्य प्रवासातील विलंब यावर आधारित ते समायोजित करा.आपल्याला अधिक आरामशीर अनुभव हवा असल्यास, आपला मुक्काम वाढवण्याचा किंवा कमी आकर्षणांवर लक्ष केंद्रित करण्याचा विचार करा.स्थानांमधील प्रवासाच्या वेळेस घटक लक्षात ठेवा.विमानतळावर आणि तेथून प्री-बुकिंग वाहतुकीची शिफारस केली जाते.
